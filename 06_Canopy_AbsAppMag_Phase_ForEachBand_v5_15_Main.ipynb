# %% [markdown]
# # Create text files of:
# # - (phase, absolute mag, error mag) and
# # - (phase, apparent mag, error mag)

# %% [markdown]
# # User interface

# %%
# USER

# To read arguments in command line
# Used in the ".py" version of this notebook.
import sys 

#--- For command line ---
# bandName = '%s'%sys.argv[1]
# Sample = '%s'%sys.argv[2]
 
#---- For notebook----
bandName = 'H'  # (Y, Y, H, K)

# Sample = 'CfA'
Sample = 'CSP' 
# Sample = 'Others' 
# Sample = 'CfA_CSP' 


#----------------

HoFix = 73.24 # 72 # Hubble constant (km/(s Mpc))
# HoFix = 72.78  # TEMPORAL: value reported by Dhawan et al 2017.

OmMFix = 0.28
OmLFix = 0.72
wFix = -1

# Print some marks to debug the code?
debug = False

# %% [markdown]
# ---------------------------------------

# %% [markdown]
# # Automatic

# %%
from snpy import *
# from numpy import * 
import numpy as np
from matplotlib import pyplot as plt
import json
import glob # To read the name of the files in a given directory

# %pylab qt 
# For CANOPY python: to show the plots in a separated Windows instead of inline.
# If used, then I don't have to put the instruction "plt.close()" at
# the end of the plot because it will show the figure and instantaneously 
# close the windows too.

5+6
# Out:
# 11

# %%
#-------- BAND --------------------

if bandName == 'J':
    filterNames = ['J2m', 'JANDI', 'J', 'Jrc1', 'Jrc2', 'Jdw']

if bandName == 'Y':
    filterNames = ['Y', 'Ydw']

if bandName == 'H':
    filterNames = ['H2m', 'HANDI', 'H', 'Hdw']

if bandName == 'K':
    filterNames = ['Ks2m', 'KANDI', 'K', 'Kd']

#-------------------- 

DataType = 'OpticalNIR' # OpticalNIR, Optical

# The kcorr uncertainties were computed during the snoopy fitting
# of the light curves?
error_kcorr = False

# Comment the CfA photometric observations flagged by Andrew Friedmann?
CommentFlaggedCfAData = True


######## (usually fixed) ########
#   Filter system
FilterSyst = 'Std_filters/'
# FilterSyst = 'CSP_filters/'

# %%
# Range of redshift data to be considered
zMinCuttoff = 0.
zMaxCuttoff = 0.1

#-----------------------------------------

# In CfA sample, remove the photometric data with the following error bars.
flag1 = 0.175; flag2 = 0.25 # OK

#-----------------------------------------

#-- Consider the light curves with -at least- the following number of data:
MinNumberOfDataInLCs=1

#-- Consider the LC that contains data in the following range -at least- only:
# phase_min = 3
# phase_max = 10

phase_min = 50
phase_max = -15

#-----------------------------------------

#   Some fixed constants

cc = 299792.458  # Speed of light (km/s)

# Peculiar velocity
# old. vpecFix = 150 # km/s. # Not used anymore

##################################3

# MainDir = '/Users/arturo/Dropbox/Research/SoftwareResearch/Snoopy/AndyLCComp_2018_02/'

# %% [markdown]
# ## Metadata: (zhel, zcmb)

# %%
DirMetadata = '/Users/arturo/Dropbox/Research/SoftwareResearch/\
Snoopy/AndyLCComp_2018_02/'

# Reading the metadata file
infoSNe_data = np.genfromtxt(DirMetadata+
                             'carrick_Flow_corrections_snnames_v1.txt',
                            dtype=['S17', float,float, 'S40',float,float,
                                   float,float,float,float,'S16', int ])

# Create a dictionary: 
# {snname: ra, dec, zhelio, e_zhel, zcmb, e_zcmb, zcmbFlow, e_zcmbFlow, code}

infoSNe_dict = {infoSNe_data['f0'][i]: np.array( [ infoSNe_data['f1'][i],
                infoSNe_data['f2'][i], 
                infoSNe_data['f4'][i]/cc, infoSNe_data['f5'][i]/cc,
                infoSNe_data['f6'][i]/cc, infoSNe_data['f7'][i]/cc,
                infoSNe_data['f8'][i]/cc, infoSNe_data['f9'][i]/cc,
                infoSNe_data['f11'][i]] )
                for i in range(len(infoSNe_data)) } 

print infoSNe_dict['sn1991T']
# [  1.88542500e+02   2.66556000e+00   5.79067269e-03   3.33564095e-06
#    3.19220839e-03   2.00138457e-05   6.60456908e-03   5.00346143e-04
#    2.00000000e+00]
# Out:
# [  1.88542500e+02   2.66556000e+00   5.79067269e-03   3.33564095e-06
#    3.19220839e-03   2.00138457e-05   9.20636903e-04   5.00346143e-04
#    2.00000000e+00]

# %% [markdown]
# ### Uploading the SED of Hsiao to compute the extinction

# %%
Ia_w, Ia_f = kcorr.get_SED(0,'H3')

# %% [markdown]
# ### Cosmology theory for $\mu(z)$

# %%
from scipy.integrate import quad as intquad

# Inverse of the dimensionless Hubble parameter
def InvEHubblePar(z, OmM, wde):
    "Dimensionless Hubble parameter"
    InvEHubbleParInt = 1.0/(np.sqrt(OmM*(1.0+z)**3.0 + (1.0-OmM)*(1.+z)**(3.*(1.+wde))))
    return InvEHubbleParInt

# ---- The luminosity distance ----
def LumDistance(z, OmM, wde, Ho):
    "Luminosity distance"
    LumDistanceVecInt = 0.
    LumDistanceVecInt = cc*(1.+z)*intquad(InvEHubblePar, 0., z, args=(OmM, wde))[0]/Ho 
    return LumDistanceVecInt


# ---- Distance modulus ----
def DistanceMu(z, OmM, wde, Ho):
    "Distance modulus"     
    DistanceMuInt = 5.0*np.log10(LumDistance(z, OmM, wde, Ho)) + 25.0
    return DistanceMuInt

#--------------------------------------------------

ztest1 = 0.1
print DistanceMu(ztest1, OmMFix, wFix, HoFix)
# 38.2572823409
# 38.2202031449
# Out:
# 38.2202031449

# %% [markdown]
# ### Generating a table of data (phase[TBmax], M, error_M) including the info of the SNe, from the "snpy" files
#
# The output data is already corrected by
# - k-correction
# - extinction by Milky Way dust
# - time dilation using the z_helio

# %%
#- Directory to save the data

DirSaveFiles = '/Users/arturo/Dropbox/Research/Articulos/10_AndyKaisey/\
10Compute/TheTemplates/'+bandName+'_band/'+FilterSyst+'1_AllData_InitialFit/\
AbsMag/'+Sample+'/'    

#- Force the creation of the directory to save the outputs.
#- "If the subdirectory does not exist then create it"
if not os.path.exists(DirSaveFiles): os.makedirs(DirSaveFiles)
# if not os.path.exists(DirSavAppMag): os.makedirs(DirSavAppMag)

#- Directory where the ".snpy" files are located:
DirLocationData = '/Users/arturo/Dropbox/Research/SoftwareResearch/\
Snoopy/AndyLCComp_2018_02/all/\
snoopy/2_Combine_Fit/'+Sample+'/'+DataType+'/Fit/'

os.chdir(DirLocationData)

# Create a list of the the ".snpy" file names: 
list_SN = glob.glob('*_StdFilt.snpy')
# tmp. list_SN = glob.glob('*_1stFit.snpy') # tmp

print len(list_SN),"SNe read with extension '_StdFilt.snpy.'"
# Out:
# 106 SNe read with extension '_StdFilt.snpy.'

# %% [markdown]
# ### Main Loop

# %%
# AUTOMATIC: THIS DOES NOT NEED USER INTERACTION

# Create a list of the the "kcorr_Mean_Std.json" file names:
# old. list_JSON = glob.glob('*_kcorr_Mean_Std.json')

log_text = open(DirSaveFiles+'Log_ListSNeWithData_in_'+bandName+'_band_'+Sample+'.log', 'w')
# log_tex2 = open(DirSavAppMag+'Log_ListSNeWithData_in_'+bandName+'_band_'+Sample+'.log', 'w')

text_line = '#'+'-'*50 + '\n'

log_text.write("# %s SNe read with extension '_StdFilt.snpy' \
in folder: \n"%len(list_SN))
log_text.write("# %s \n"%DirLocationData)
log_text.write("%s \n"%('-'*40))
log_text.write('# '+bandName+'_band in the following SNe: \n')
# log_tex2.write(bandName+'_band in the following SNe: \n')

print 'SNe with data in band '+bandName+':'

countSN_nir = 0 # Count SNe with data in a given NIR band
# count_nodata = 0 # Count SNe with no data in a given NIR band.
# SNe_nodata = [] # list of SNe with no data in a given NIR band.

for sn in list_SN: # Loop over the SNe.

    s=get_sn(sn) # upload .snpy info
    
    if debug: print "Step 1: %s SN to work out."%s.name
        
    # Reset arrays and variables
    data_all_np  = np.array([0.,0.,0.,0.,0.,0.,0.])
    Flag_LC_passed_cutoffs = 0  
    CountNumSimilarBands = 0
    count_AllNumDataInLC = 0
    
    # The kcorr uncertainties were computed during the snoopy fitting
    # of the light curves?
    if error_kcorr == True:    
        # upload the .json dictionary containing the k-corr uncertainties
        with open(sn[:-12]+'kcorr_Mean_Std.json','r') \
as outfile: s_errorKcorr = json.load(outfile)  
            
    zhelio     = infoSNe_dict[s.name][2]
    err_zhelio = infoSNe_dict[s.name][3]
    
    # Flag to determine the appropiate z_cmb:
    flag_zcmb  = infoSNe_dict[s.name][8]
    if flag_zcmb > 0.1:
        zcmb       = infoSNe_dict[s.name][4]
        err_zcmb   = infoSNe_dict[s.name][5]
    else:
        zcmb       = infoSNe_dict[s.name][6]
        err_zcmb   = infoSNe_dict[s.name][7]
        
    if debug: print 'Step 3: z_CMB defined; done.'

    if zhelio > zMinCuttoff and zhelio < zMaxCuttoff:

        if debug: print 'Step 4: (First cutoff) SNe within the z_helio cutoff; done'
        if debug: print "Step 5: Loop over filters:"
            
        # Loop over all the variants of filters names in a given band.
        for band in filterNames: 
            
            if debug: print band
                
            # Reset arrays
            data_np = np.array([0.,0.,0.,0.,0.,0.,0.])
            data_band_np = np.array([0.,0.,0.,0.,0.,0.,0.])
            
            # Check if the LC has data inside my cutoffs.
            if (band in s.data.keys() and
                (s.data[band].MJD[0] -s.Tmax)/(1+zhelio) <= phase_min and
                (s.data[band].MJD[-1]-s.Tmax)/(1+zhelio) >= phase_max and
                len(s.data[band].MJD) >= MinNumberOfDataInLCs):
                
                # If the LC has data inside my cutoffs, flag it
                # This flag will be used when writting the data to a
                # text file.
                Flag_LC_passed_cutoffs = 1

                if debug: print 'Step 6: LC with data in %s band \
and inside my cutoffs.'%band

                #------- The extinction A_lambda --------
                R_F = fset[band].R(wave=Ia_w, flux=Ia_f, Rv=3.1)
                Alamb = R_F * s.EBVgal
                e_Alamb = R_F * s.e_EBVgal

                #------- distance modulus (LCDM)
                mu_LCDM = DistanceMu(zcmb, OmMFix, wFix, HoFix)
                
                if debug: print 'HERE 7'

                #------------------------------------------------------------------------
                #   WRITTING THE HEADERS IN THE TEXT FILE
                
                # Count the number of similar bands in the same SNe (e.g., J, J2m)
                CountNumSimilarBands += 1
                    
                # Create the text file to write the metadata info only.
                if CountNumSimilarBands == 1: 
                    SN_txtfile = open(DirSaveFiles+sn[0:18]+'_'+Sample+'_'+
                                      bandName+'.txt', 'w')

                if CountNumSimilarBands == 1:
                    SN_txtfile.write("# {0} \n".format(s.name))
                    # SN_txtfil2.write("# {0}    # SN name \n".format(s.name))

                    # SN_txtfile.write("# \n")
                    SN_txtfile.write("%-13.6f  %.6f  %.6f  %.6f  -1       -1  -1 # \
(zcmb, err_zcmb, zhelio, err_zhelio) \n"%(
                            zcmb, err_zcmb, zhelio, err_zhelio))
                    # SN_txtfil2.write("{0}  {1}  {2}  {3}  00.000  00.000 00.000 # \
    # (zcmb, err_zcmb, zhelio, err_zhelio) metadata file \n".format(zcmb, err_zcmb,
    #                                                              zhelio, err_zhelio ))
                    # SN_txtfile.write("# \n")
                    SN_txtfile.write("%-13.6f  %.6f  %.6f   -1       -1       -1  -1 # \
(dm15, err_dm15, stretch) \n"%(
                            s.dm15, s.e_dm15, s.ks_s))
    #                SN_txtfil2.write("{0}  {1}  {2}   00.000  00.000 00.000 00.000 # \
    # (dm15, err_dm15, stretch) \n".format(s.dm15, s.e_dm15, s.ks_s))

                    # SN_txtfile.write(" \n")
                    SN_txtfile.write("%-13.6f  %.6f  %.6f  -1       -1       -1  -1 # \
(mu_Snoopy, err_mu_Snoopy, mu_LCDM) \n"%(
                            s.DM, s.e_DM, mu_LCDM))
    #                 SN_txtfil2.write("{0}  {1}  {2}  00.000  00.000  00.000 00.000 # \
    # (mu_Snoopy, err_mu_Snoopy, mu_LCDM) \n".format(s.DM, s.e_DM, mu_LCDM))

                    # SN_txtfile.write(" \n")
                    SN_txtfile.write("%-13.6f  %.6f  %.6f  %.6f  %.6f -1  -1 # \
(E(B-V)_MW, err_E(B-V)_MW, Alamb, err_Alamb, R_F) \n"%(
                            s.EBVgal, s.e_EBVgal, Alamb, e_Alamb, R_F))
    #                SN_txtfil2.write("{0}  {1}  {2}  {3}  {4} 00.000  00.000 # \
    # (E(B-V)_MW, err_E(B-V)_MW, Alamb, err_Alamb, R_F) \n".format(s.EBVgal, s.e_EBVgal,
    #                                                              Alamb, e_Alamb, R_F))

                    # SN_txtfile.write(" \n")
                    SN_txtfile.write("%-13.6f  %.6f  -1        -1        -1       -1  -1 # \
(E(B-V)_host, err_E(B-V)_host) \n"%(
                            s.EBVhost, s.e_EBVhost))
    #                 SN_txtfil2.write("{0}  {1}  00.000  00.000 00.000 00.000 00.000 # \
    # (E(B-V)_host, err_E(B-V)_host) \n".format(s.EBVhost, s.e_EBVhost))

                    # SN_txtfile.write(" \n")
                    SN_txtfile.write("%-13.6f  %.6f  -1        -1        -1       -1  -1 # \
(T_Bmax, err_T_Bmax) \n"%(s.Tmax, s.e_Tmax))
    #                 SN_txtfil2.write("{0}  {1}  00.000  00.000 00.000 00.000 00.000 # \
    # (T_Bmax, err_T_Bmax) \n".format(s.Tmax, s.e_Tmax))

                    SN_txtfile.write("-1  -1  -1  -1  -1  -1  -1 # Free slot \n")


                    SN_txtfile.write("-1  -1  -1  -1  -1  -1  -1 # Free slot \n")


                    SN_txtfile.write("# Assuming flat LCDM with (Om={0}, OL={1}, w={2}, \
Ho={3}) \n".format(OmMFix, OmLFix, wFix, HoFix))

                    SN_txtfile.write('#------------------------------------------------- \n')
                    SN_txtfile.write("#  %s \n"%band)
                    SN_txtfile.write('#Phase(TBmax) Abs mag  Err_Absmag  App mag  \
Err_appmag   kcorr    err_kcorr  \n')
                    
                    SN_txtfile.close()

                #------------------------------------------------------------------------
                #   SAVING TO AN ARRAY THE PHOTOMETRY

                # Retriving the error in EBVgal
                # e_EBVgal = dust_getval.get_dust_sigma_RADEC(s.ra, s.decl, calibration='SF11')

                if debug: print 'Step 9: Metadata info written in the text file; done.'
                
                # Count the number data points in the LC, in a given band and SN.
                count_NumDataInLC = 0
                
                for i in range(len(s.data[band].MJD)): # Loop over MJD in a given band

                    #---------------------------------------------
                    # Remove bad photometric data points in CfA sample based on the flag
                    # in the error value:

                    # Reset variable:
                    CommentFlag = 0 # = "Don't comment this line"
                    CommentText = ''
                    
                    if CommentFlaggedCfAData == False: 
                        CommentText = ''

                    elif CommentFlaggedCfAData == True:
                        if (Sample == 'CfA' and (s.data[band].e_mag[i] == flag1 or
                              s.data[band].e_mag[i] == flag2)):
                            CommentFlag = 1
                        else: CommentFlag = 0
                            
                    # Define the err_kcorr value:
                    if error_kcorr == True:
                            err_kcorr = s_errorKcorr[band]['%s'%s.data[band].MJD[i]][1]
                    else: err_kcorr = 0.

                    #-------------
                    # Save the good photometry to an array:
                    
                    data_np = np.array([ 

                        CommentFlag,

                        # phase:
                        (s.data[band].MJD[i]-s.Tmax)/((1+zhelio)*s.ks_s),
                        
                        # Abs mag: kcorrected, MWdust corrected, and distance
                        # modulus subtracted:
                        s.data[band].mag[i] - s.ks[band][i] - Alamb - mu_LCDM,

                       # Total uncertainty for abs mag =
                       # = (e_mag^2 + e_Alamb^2 + e_kcorr^2)^(-1/2)
                       np.sqrt((s.data[band].e_mag[i])**2 + e_Alamb**2 +
                       err_kcorr**2 ),

                       # Apparent magnitude: MWdust corrected
                       s.data[band].mag[i] - Alamb,

                       # Apparent magnitude error
                       np.sqrt((s.data[band].e_mag[i])**2 + e_Alamb**2),

                       # k-corr
                       s.ks[band][i],

                       # k-corr error
                       err_kcorr       ])
                    
                    # print "%s index"%i
                    if i==0:
                        data_band_np = data_np
                        # print data_band_np
                    elif i>0:
                        data_band_np = np.vstack((data_band_np, data_np))
                        # print data_band_np
                        
                    count_AllNumDataInLC += 1
                    count_NumDataInLC += 1 
                    # print "%s datum; done."%count_NumDataInLC
                        
                    # <<----- end loop over MJD, for a given type of band.
                    
                if debug: 
                    print "Step 11. %s data in band %s; done."%(
                                count_NumDataInLC, band)
                if debug: print 'Step 12. Loop over MJD for band %s; done'%band
                    
                log_text.write('%s \n'%sn)

                # --- Save to an array all the good photometry in a given band
                # if band in s.data.keys():
                if CountNumSimilarBands == 1:
                    data_all_np = data_band_np
                else:
                    data_all_np =  np.vstack((data_all_np, data_band_np))
                    
            # <<----- end loop over bands.
            
        if debug: print "Step 13. %s total number of data in all \
the bands of the same type"%count_AllNumDataInLC
            
        #---------------------------------------
        
        #------ Reorganize the data based dates -----
        
        
        # -------- Write the array to a text file --------
        # Open the already created text file that for now contains the 
        # SNe metadata info only.
        
        if Flag_LC_passed_cutoffs == 1:
            
            SN_txtfile = open(DirSaveFiles+sn[0:18]+'_'+Sample+'_'+
                                  bandName+'.txt', 'a')
            
            try:
                # Make a copy to order it
                # data_all_2_np = np.array([]) # Reset
                # data_all_2_np = data_all_np
                # Sort the array in increasing order.
                # data_all_2_np[data_all_2_np[:,1].argsort()]
                # test6[test6[:,1].argsort()]
                
                # Sort the array in increasing order.
                data_all_2_np = np.sort(data_all_np.view('f8,f8,f8,f8,f8,f8,f8,f8'), 
                                        order=['f1'], axis=0).view(np.float)
            
                for i1 in range(len(data_all_2_np)):
                    if data_all_2_np[i1][0] == 0: CommentText = ''
                    else: CommentText = '##'
                    SN_txtfile.write("%s%-9.5f   %.6f  %.6f  %.6f  %.6f  %10.6f  %.6f\n"%(
                            CommentText,
                            data_all_2_np[i1][1], data_all_2_np[i1][2], data_all_2_np[i1][3],
                            data_all_2_np[i1][4], data_all_2_np[i1][5], data_all_2_np[i1][6],
                            data_all_2_np[i1][7]) )
                    
                if debug: print "Step 15. All %s data  written to the text file; done."%len(data_all_2_np)
                    
            # When there is just one datum in the LC:
            except:
                if data_all_np[0] == 0: CommentText = ''
                else: CommentText = '##'
                SN_txtfile.write("%s%-9.5f   %.6f  %.6f  %.6f  %.6f  %10.6f  %.6f\n"%(
                            CommentText,
                            data_all_np[1], data_all_np[2], data_all_np[3],
                            data_all_np[4], data_all_np[5], data_all_np[6],
                            data_all_np[7]))
                if debug: print "Step 15. Only one datum written to the text file; done."
                
                
            SN_txtfile.close()
            # Count number SNe with NIR data.
            countSN_nir += 1
            print '%r) %s, done.'%(countSN_nir, sn[0:36])
        
        #--------------------------------------- 
        
    else: print "SN with z <", zMinCuttoff,":", s.name
        
    if debug: print text_line
        
    # <<---- End loop over SNe.

log_text.write("# %s SNe in this list. \n"%countSN_nir)
log_text.close()
# log_tex2.close()

print "   "
print "# %r SNe in subsample %s with data in generic %s band: done. "%(
        countSN_nir, Sample, bandName)
print "# %s SNe read with extension '_StdFilt.snpy.'"%len(list_SN)
# print "# %s SNe with no data in %s band or less than %s observations."%(
#         count_nodata, bandName, MinNumberOfDataInLCs)
# print "# The SNe are:"
# Out:
# SNe with data in band H:
# Step 1: sn1999ee SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 33 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 33 total number of data in all the bands of the same type
# Step 15. All 33 data > 1 written to the text file; done.
# 1) sn1999ee__U_45_B_118_V_126_R_53_I_10, done.
# #--------------------------------------------------
#
# Step 1: sn2000bh SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 21 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 21 total number of data in all the bands of the same type
# Step 15. All 21 data > 1 written to the text file; done.
# 2) sn2000bh__B_12_V_12_R_9_I_11_Y_CSP_6, done.
# #--------------------------------------------------
#
# Step 1: sn2000ca SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 11 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 11 total number of data in all the bands of the same type
# Step 15. All 11 data > 1 written to the text file; done.
# 3) sn2000ca__U_6_B_18_V_18_R_18_I_18_J_, done.
# #--------------------------------------------------
#
# Step 1: sn2001ba SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 14 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 4) sn2001ba__B_30_V_34_I_33_J_CSP_15_H_, done.
# #--------------------------------------------------
#
# Step 1: sn2004dt SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2004ef SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 5 total number of data in all the bands of the same type
# Step 15. All 5 data > 1 written to the text file; done.
# 5) sn2004ef_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2004eo SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 17 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 17 total number of data in all the bands of the same type
# Step 15. All 17 data > 1 written to the text file; done.
# 6) sn2004eo_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2004ey SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 14 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 7) sn2004ey_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2004gs SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 7 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 7 total number of data in all the bands of the same type
# Step 15. All 7 data > 1 written to the text file; done.
# 8) sn2004gs_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2004gu SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 2 total number of data in all the bands of the same type
# Step 15. All 2 data > 1 written to the text file; done.
# 9) sn2004gu_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005al SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 10 total number of data in all the bands of the same type
# Step 15. All 10 data > 1 written to the text file; done.
# 10) sn2005al_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005am SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 9 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 11) sn2005am_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005be SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005bg SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005bo SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005el SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 20 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 24 total number of data in all the bands of the same type
# Step 15. All 24 data > 1 written to the text file; done.
# 12) sn2005el_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005eq SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 12 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 13 total number of data in all the bands of the same type
# Step 15. All 13 data > 1 written to the text file; done.
# 13) sn2005eq_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005hc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 3 total number of data in all the bands of the same type
# Step 15. All 3 data > 1 written to the text file; done.
# 14) sn2005hc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005iq SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 12 total number of data in all the bands of the same type
# Step 15. All 12 data > 1 written to the text file; done.
# 15) sn2005iq_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005ir SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005kc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 16 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 16 total number of data in all the bands of the same type
# Step 15. All 16 data > 1 written to the text file; done.
# 16) sn2005kc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005ke SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 35 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 14 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 49 total number of data in all the bands of the same type
# Step 15. All 49 data > 1 written to the text file; done.
# 17) sn2005ke_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005ki SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 13 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 17 total number of data in all the bands of the same type
# Step 15. All 17 data > 1 written to the text file; done.
# 18) sn2005ki_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005ku SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005lu SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005M SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 20 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 20 total number of data in all the bands of the same type
# Step 15. All 20 data > 1 written to the text file; done.
# 19) sn2005M_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005mc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2005na SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 7 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 20) sn2005na_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2005W SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2006ax SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 23 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 31 total number of data in all the bands of the same type
# Step 15. All 31 data > 1 written to the text file; done.
# 21) sn2006ax_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006bh SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 17 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 19 total number of data in all the bands of the same type
# Step 15. All 19 data > 1 written to the text file; done.
# 22) sn2006bh_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006bt SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 9 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 23) sn2006bt_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006ef SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2006ej SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 2 total number of data in all the bands of the same type
# Step 15. All 2 data > 1 written to the text file; done.
# 24) sn2006ej_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006et SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 28 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 32 total number of data in all the bands of the same type
# Step 15. All 32 data > 1 written to the text file; done.
# 25) sn2006et_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006fw SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2006gj SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 7 total number of data in all the bands of the same type
# Step 15. All 7 data > 1 written to the text file; done.
# 26) sn2006gj_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006gt SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 2 total number of data in all the bands of the same type
# Step 15. All 2 data > 1 written to the text file; done.
# 27) sn2006gt_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006hb SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 12 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 12 total number of data in all the bands of the same type
# Step 15. All 12 data > 1 written to the text file; done.
# 28) sn2006hb_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006hx SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 8 total number of data in all the bands of the same type
# Step 15. All 8 data > 1 written to the text file; done.
# 29) sn2006hx_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006is SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 30) sn2006is_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006kf SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 18 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 18 total number of data in all the bands of the same type
# Step 15. All 18 data > 1 written to the text file; done.
# 31) sn2006kf_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006lu SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2006ob SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 2 total number of data in all the bands of the same type
# Step 15. All 2 data > 1 written to the text file; done.
# 32) sn2006ob_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006os SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 7 total number of data in all the bands of the same type
# Step 15. All 7 data > 1 written to the text file; done.
# 33) sn2006os_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2006py SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2006X SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 24 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 18 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 42 total number of data in all the bands of the same type
# Step 15. All 42 data > 1 written to the text file; done.
# 34) sn2006X_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007A SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 3 total number of data in all the bands of the same type
# Step 15. All 3 data > 1 written to the text file; done.
# 35) sn2007A_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007af SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 38 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 48 total number of data in all the bands of the same type
# Step 15. All 48 data > 1 written to the text file; done.
# 36) sn2007af_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007ai SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 6 total number of data in all the bands of the same type
# Step 15. All 6 data > 1 written to the text file; done.
# 37) sn2007ai_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007as SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 11 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 13 total number of data in all the bands of the same type
# Step 15. All 13 data > 1 written to the text file; done.
# 38) sn2007as_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007bc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 8 total number of data in all the bands of the same type
# Step 15. All 8 data > 1 written to the text file; done.
# 39) sn2007bc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007bd SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 40) sn2007bd_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007bm SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 41) sn2007bm_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007ca SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 42) sn2007ca_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007cg SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2007hj SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 25 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 11 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 36 total number of data in all the bands of the same type
# Step 15. All 36 data > 1 written to the text file; done.
# 43) sn2007hj_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007hx SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2007jd SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2007jg SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 1 total number of data in all the bands of the same type
# Step 15. Only one datum written to the text file; done.
# 44) sn2007jg_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007le SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 24 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 32 total number of data in all the bands of the same type
# Step 15. All 32 data > 1 written to the text file; done.
# 45) sn2007le_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007nq SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 3 total number of data in all the bands of the same type
# Step 15. All 3 data > 1 written to the text file; done.
# 46) sn2007nq_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007on SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 36 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 13 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 49 total number of data in all the bands of the same type
# Step 15. All 49 data > 1 written to the text file; done.
# 47) sn2007on_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007S SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 21 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 12 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 33 total number of data in all the bands of the same type
# Step 15. All 33 data > 1 written to the text file; done.
# 48) sn2007S_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007so SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 6 total number of data in all the bands of the same type
# Step 15. All 6 data > 1 written to the text file; done.
# 49) sn2007so_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007sr SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 21 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 31 total number of data in all the bands of the same type
# Step 15. All 31 data > 1 written to the text file; done.
# 50) sn2007sr_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007st SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 10 total number of data in all the bands of the same type
# Step 15. All 10 data > 1 written to the text file; done.
# 51) sn2007st_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2007ux SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 11 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 16 total number of data in all the bands of the same type
# Step 15. All 16 data > 1 written to the text file; done.
# 52) sn2007ux_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008ar SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 7 total number of data in all the bands of the same type
# Step 15. All 7 data > 1 written to the text file; done.
# 53) sn2008ar_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008bc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 18 total number of data in all the bands of the same type
# Step 15. All 18 data > 1 written to the text file; done.
# 54) sn2008bc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008bf SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 5 total number of data in all the bands of the same type
# Step 15. All 5 data > 1 written to the text file; done.
# 55) sn2008bf_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008bq SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 3 total number of data in all the bands of the same type
# Step 15. All 3 data > 1 written to the text file; done.
# 56) sn2008bq_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008bt SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 1 total number of data in all the bands of the same type
# Step 15. Only one datum written to the text file; done.
# 57) sn2008bt_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008bz SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2008C SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 9 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 12 total number of data in all the bands of the same type
# Step 15. All 12 data > 1 written to the text file; done.
# 58) sn2008C_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008cc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 11 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 13 total number of data in all the bands of the same type
# Step 15. All 13 data > 1 written to the text file; done.
# 59) sn2008cc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008cf SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 10 total number of data in all the bands of the same type
# Step 15. All 10 data > 1 written to the text file; done.
# 60) sn2008cf_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008ff SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 18 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 13 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 31 total number of data in all the bands of the same type
# Step 15. All 31 data > 1 written to the text file; done.
# 61) sn2008ff_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008fl SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 9 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 15 total number of data in all the bands of the same type
# Step 15. All 15 data > 1 written to the text file; done.
# 62) sn2008fl_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008fp SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# ...
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 4 total number of data in all the bands of the same type
# Step 15. All 4 data > 1 written to the text file; done.
# 65) sn2008fu_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008fw SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 6 total number of data in all the bands of the same type
# Step 15. All 6 data > 1 written to the text file; done.
# 66) sn2008fw_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008gg SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 67) sn2008gg_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008gl SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 8 total number of data in all the bands of the same type
# Step 15. All 8 data > 1 written to the text file; done.
# 68) sn2008gl_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008go SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2008gp SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 17 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 17 total number of data in all the bands of the same type
# Step 15. All 17 data > 1 written to the text file; done.
# 69) sn2008gp_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008hj SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 6 total number of data in all the bands of the same type
# Step 15. All 6 data > 1 written to the text file; done.
# 70) sn2008hj_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008hu SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 3 total number of data in all the bands of the same type
# Step 15. All 3 data > 1 written to the text file; done.
# 71) sn2008hu_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008hv SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 20 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 23 total number of data in all the bands of the same type
# Step 15. All 23 data > 1 written to the text file; done.
# 72) sn2008hv_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008ia SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 18 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 28 total number of data in all the bands of the same type
# Step 15. All 28 data > 1 written to the text file; done.
# 73) sn2008ia_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008O SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 5 total number of data in all the bands of the same type
# Step 15. All 5 data > 1 written to the text file; done.
# 74) sn2008O_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2008R SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 1 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 9 total number of data in all the bands of the same type
# Step 15. All 9 data > 1 written to the text file; done.
# 75) sn2008R_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009aa SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 27 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 5 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 32 total number of data in all the bands of the same type
# Step 15. All 32 data > 1 written to the text file; done.
# 76) sn2009aa_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009ab SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 14 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 77) sn2009ab_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009ad SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 17 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 17 total number of data in all the bands of the same type
# Step 15. All 17 data > 1 written to the text file; done.
# 78) sn2009ad_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009ag SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 28 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 3 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 31 total number of data in all the bands of the same type
# Step 15. All 31 data > 1 written to the text file; done.
# 79) sn2009ag_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009cz SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 12 total number of data in all the bands of the same type
# Step 15. All 12 data > 1 written to the text file; done.
# 80) sn2009cz_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009D SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 6 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 14 total number of data in all the bands of the same type
# Step 15. All 14 data > 1 written to the text file; done.
# 81) sn2009D_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009dc SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 15 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 19 total number of data in all the bands of the same type
# Step 15. All 19 data > 1 written to the text file; done.
# 82) sn2009dc_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009ds SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 10 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 2 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 12 total number of data in all the bands of the same type
# Step 15. All 12 data > 1 written to the text file; done.
# 83) sn2009ds_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009I SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 7 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 7 total number of data in all the bands of the same type
# Step 15. All 7 data > 1 written to the text file; done.
# 84) sn2009I_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009J SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2009le SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 4 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 13. 4 total number of data in all the bands of the same type
# Step 15. All 4 data > 1 written to the text file; done.
# 85) sn2009le_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
# Step 1: sn2009P SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Hdw
# Step 13. 0 total number of data in all the bands of the same type
# #--------------------------------------------------
#
# Step 1: sn2009Y SN to work out.
# Step 3: z_CMB defined; done.
# Step 4: (First cutoff) SNe within the z_helio cutoff; done
# Step 5: Loop over filters:
# H2m
# HANDI
# H
# Step 6: LC with data in H band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 18 data in band H; done.
# Step 12. Loop over MJD for band H; done
# Hdw
# Step 6: LC with data in Hdw band and inside my cutoffs.
# HERE 7
# Step 9: Metadata info written in the text file; done.
# Step 11. 8 data in band Hdw; done.
# Step 12. Loop over MJD for band Hdw; done
# Step 13. 26 total number of data in all the bands of the same type
# Step 15. All 26 data > 1 written to the text file; done.
# 86) sn2009Y_dummytext_CSP_StdFilt.snpy, done.
# #--------------------------------------------------
#
#
# # 86 SNe in subsample CSP with data in generic H band: done.
# # 106 SNe read with extension '_StdFilt.snpy.'
